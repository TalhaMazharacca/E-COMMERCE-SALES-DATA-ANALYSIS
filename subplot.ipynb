# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4,5]
y=[30,70,50,60,40]

y2=[45,27,35,43,20]
y3=[45,27,70,50,60]

plt.subplot(1,2,1)#(Row,Column,plot no.
plt.plot(x,y,label="male")
plt.subplot(1,2,1)#(Row,Column,plot no.
plt.legend()
plt.show()

x1=[5,6,7,8,9]
y1=[40,25,30,35,20]

plt.plot(x1,y1,label="Female",color="hotpink")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4,5]
y=[30,70,50,60,40]

y2=[45,27,35,43,20]
y3=[45,27,70,50,60]

plt.subplot(1,2,1)#(Row,Column,plot no.
plt.plot(x,y,label="male")
plt.legend()

y1=[40,25,30,35,20]

plt.subplot(1,2,2)
plt.plot(x,y1,label="Female",color="hotpink")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4,5]
y=[30,70,50,60,40]

plt.subplot(1,3,1)#(Row,Column,plot no.
plt.plot(x,y,label="male")
plt.legend()


x=[5,6,7,8,9]
y=[40,25,30,35,20]

plt.subplot(1,3,2)
plt.plot(x,y,label="Female",color="hotpink")
plt.legend()



x=[1,4,8,9,11]
y=[45,27,35,43,20]

plt.subplot(1,3,3)
plt.plot(x,y,label="Kid",color="Black",)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4,5]
y=[30,70,50,60,40]

plt.subplot(2,3,1)#(Row,Column,plot no.
plt.plot(x,y,label="male")
plt.legend()


x=[5,6,7,8,9]
y=[40,25,30,35,20]

plt.subplot(2,3,2)
plt.plot(x,y,label="Female",color="hotpink")
plt.legend()



x=[1,4,8,9,11]
y=[45,27,35,43,20]

plt.subplot(2,3,3)
plt.plot(x,y,label="Kid",color="Black",)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4,5]
y=[30,70,50,60,40]

plt.subplot(2,2,1)#(Row,Column,Chart no)
plt.bar(x,y,label="male")
plt.legend()


x=[5,6,7,8,9]
y=[40,25,30,35,20]

plt.subplot(2,2,2)
plt.plot(x,y,label="Female",color="hotpink")
plt.legend()



x=[1,4,8,9,11]
y=[45,27,35,43,20]

plt.subplot(2,2,3)
plt.plot(x,y,label="Kid",color="Black",)
plt.legend()


x=[1,4,8,9,11]
y=[40,25,33,49,21]

plt.subplot(2,2,4)
plt.plot(x,y,label="Blank",color="Green",)
plt.legend()
plt.show()
